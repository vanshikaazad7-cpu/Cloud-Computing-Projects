# %% [markdown]
# <a href="https://colab.research.google.com/github/vanshikaazad7-cpu/DBMS-LAB-PYTHON/blob/main/PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
07-08-26

# %%
print(10+20)
# Out:
# 30

# %%
#python uses interpreter

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))
print(f"Hello {name}, next year you will be {age + 1} years old.")
# Out:
# Enter your name: VAN
# Enter your age: 19
# Hello VAN, next year you will be 20 years old.
