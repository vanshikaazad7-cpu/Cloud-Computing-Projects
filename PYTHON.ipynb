# %% [markdown]
# <a href="https://colab.research.google.com/github/vanshikaazad7-cpu/Cloud-Computing-Projects/blob/main/PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
07-08-26

# %%
print(10+20)
# Out:
# 30

# %%
#python uses interpreter
