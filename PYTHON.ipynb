# %% [markdown]
# <a href="https://colab.research.google.com/github/vanshikaazad7-cpu/DBMS-LAB-PYTHON-COLLEGE/blob/main/PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
07-08-26

# %%
print(10+20)
# Out:
# 30

# %%
#python uses interpreter

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))
print(f"Hello {name}, next year you will be {age + 1} years old.")
# Out:
# Enter your name: VAN
# Enter your age: 19
# Hello VAN, next year you will be 20 years old.

# %% [markdown]
# **Integer (int):** Starts at 28 bytes for a small number (e.g., 0). As numbers grow larger, Python dynamically allocates extra bytes (typically in 4-byte increments).
#
# **Float (float):** Fixed at 24 bytes (stores 64-bit double-precision IEEE 754 floating-point values).
#
# **Boolean (bool):** Uses 28 bytes (since True and False are subclasses of int).
#
# **NoneType (None):** Uses 16 bytes.
#
# **String (str):** Starts around 49 bytes for an empty string "" and grows based on character length and encoding (ASCII vs. Unicode).
#
# **List (list):** An empty list takes 56 bytes + 8 bytes per item pointer.
#
# **Dictionary (dict):** An empty dictionary takes around 64 to 232 bytes depending on allocation and key-value entries.
#
# Python uses dynamic, arbitrary-precision integers (bignums), meaning an integer can grow to use as much memory as your system's RAM allows.
#
# Python has no memory specifness , its memory is infinite.

# %%
a,b,c,d= 10,20,30,40
print(id(a))
print(id(b))
print(id(c))
print(id(d))
#The id() function returns a unique identifier for an object,
#which remains constant during its lifetime.
#In Python, this is typically the memory address of the object.
# Out:
# 11645640
# 11645960
# 11646280
# 11646600

# %% [markdown]
# A variable is a container used to store any type of data.
# the variable name is an **identifier** and the value assigned to it is called a **literal**.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Number Datatypes store numerical values and they are immutale datatype means changing the value of the datatype results in a newly allocated object.
#
# int (Integer): Whole numbers of arbitrary length (e.g., 10, -500, 10000000).
#
# float (Floating Point): Real numbers with decimal points (e.g., 3.14, -0.001).
#
# complex (Complex): Numbers with real and imaginary parts (e.g., 3 + 4j).( why do we consider j - ambiguity due to the use of i ) j is the square root of -1 .

# %%
a=input()
print(type(a))
#By default, the input() function always reads the input as a string.
# Out:
# 4
# <class 'str'>

# %%
# check for vowel or consonent
ch = input("Enter a single character: ").lower()
if len(ch) == 1 and ch.isalpha():
    if ch in ['a', 'e', 'i', 'o', 'u']:
        print(f"'{ch}' is a Vowel.")
    else:
        print(f"'{ch}' is a Consonant.")
else:
    print("Invalid input! Please enter a single alphabetic letter.")
# Out:
# Enter a single character: w
# 'w' is a Consonant.

# %%
# print days of week
days= {
    1: "Monday",
    2: "Tuesday",
    3: "Wednesday",
    4: "Thursday",
    5: "Friday",
    6: "Saturday",
    7: "Sunday"
}
x= int(input("Enter day number"))
print(days.get(x, "Invalid input! Please enter a number between 1 and 7."))
# Out:
# Enter day number4
# Thursday

# %%
# WAP TO PRINT THE ENTERED DIGIT IN WORDS
x= int(input("Enter a number between 0 and 9 "))
numbers={
    0:"Zero",
    1:"One",
    2:"Two",
    3:"Three",
    4:"Four",
    5:"Five",
    6:"Six",
    7:"Seven",
    8:"Eight",
    9:"Nine"
}
print(numbers.get(x, "Invalid input! Please enter a number between 0 and 9."))
# Out:
# Enter a number between 0 and 9 3
# Three

# %%
# wap to check whether a year is leap year
year= int(input("Enter a year"))
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print(f"{year} is a leap year.")
else:
    print(f"{year} is not a leap year.")
# Out:
# Enter a year2022
# 2022 is not a leap year.

# %%
# WAP to calculate the electricity bill for 1st 100 units- 3 rs, >100 <=200 - 5 rs, >200 <=500- 7rs, >500 - 10rs
units= int(input("Enter Units consumed="))
if units <=100:
    bill= units*3
elif units >100 and units <=200:
    bill= (100*3) + ((units-100)*5)
elif units >200 and units<=500:
    bill= (100*3) + (100*5) + ((units-200)*7)
else:
    bill= (100*3) + (100*5) + (300*7)+ (units-500)*10

print(f"Rs {bill} units consumed")
